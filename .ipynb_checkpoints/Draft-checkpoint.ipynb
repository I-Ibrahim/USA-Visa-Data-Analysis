# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1) Load and Merge Data

# %%
h1b2016=pd.read_excel('H-1B_Disclosure_Data_FY16.xlsx')
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0       I-200-12240-490687  CERTIFIED-WITHDRAWN     2012-08-27    2015-10-16
# 1       I-200-13053-847481  CERTIFIED-WITHDRAWN     2013-02-25    2016-01-13
# 2       I-200-13088-054259  CERTIFIED-WITHDRAWN     2013-04-23    2015-12-10
# 3       I-200-13144-034110  CERTIFIED-WITHDRAWN     2013-05-24    2016-01-19
# 4       I-200-13172-415116            WITHDRAWN     2013-06-26    2016-05-20
# 5       I-200-13219-306739  CERTIFIED-WITHDRAWN     2013-08-07    2015-10-30
# 6       I-200-13317-861241  CERTIFIED-WITHDRAWN     2013-11-20    2016-02-22
# 7       I-200-14037-755844  CERTIFIED-WITHDRAWN     2014-02-07    2015-11-16
# 8       I-200-14042-183163  CERTIFIED-WITHDRAWN     2014-02-19    2015-11-18
# 9       I-200-14072-690535            WITHDRAWN     2014-03-19    2016-03-03
# 10      I-200-14078-894857  CERTIFIED-WITHDRAWN     2014-03-19    2016-01-27
# ...

# %%
h1b2015=pd.read_excel('H-1B_Disclosure_Data_FY16.xlsx')

# %%
h1b2014=pd.read_excel('H-1B_FY14_Q4.xlsx')

# %%
# Add the a column with the Year of each prior to merging in case one needs to refer back to certain initial datasets

h1b2016['Year']=2016
h1b2015['Year']=2015
h1b2014v2['Year']=2014

# Merge

h1boverall=pd.concat([h1b2016, h1b2015, h1b2014v2], axis=0)

# %% [markdown]
#
# Some columns in the 2014 dataset are named differently than the 2015 and 2016 datasets. Thus I will first rename said columns so that when merging the columns pandas picks this up

# %%
h1b2014v2=h1b2014.rename(columns={'LCA_CASE_SUBMIT':'CASE_SUBMITTED',
                                  'LCA_CASE_EMPLOYMENT_START_DATE':'EMPLOYMENT_START_DATE',
                                  'LCA_CASE_EMPLOYMENT_END_DATE':'EMPLOYMENT_END_DATE',
                                  'LCA_CASE_EMPLOYER_NAME':'EMPLOYER_NAME',
                                  'LCA_CASE_EMPLOYER_CITY':'EMPLOYER_CITY',
                                  'LCA_CASE_EMPLOYER_STATE':'EMPLOYER_STATE',
                                  'FULL_TIME_POS':'FULL_TIME_POSITION',
                                  'LCA_CASE_JOB_TITLE':'JOB_TITLE',
                                  'LCA_CASE_WAGE_RATE_FROM':'WAGE_RATE_OF_PAY_FROM',
                                  'LCA_CASE_WAGE_RATE_TO':'WAGE_RATE_OF_PAY_TO',
                                  'LCA_CASE_WAGE_RATE_UNIT':'WAGE_UNIT_OF_PAY'
                                 })

# %% [markdown]
# # Feature Selection

# %%
h1boverallv2=h1boverall.drop(['EMPLOYER_ADDRESS', 'EMPLOYER_POSTAL_CODE', 'EMPLOYER_PROVINCE',
                           'EMPLOYER_PHONE', 'EMPLOYER_PHONE_EXT','AGENT_ATTORNEY_NAME','AGENT_ATTORNEY_CITY',
                           'AGENT_ATTORNEY_STATE','SOC_CODE', 'SOC_NAME', 'NAIC_CODE', 'PW_SOURCE_OTHER', 
                           'PW_SOURCE_YEAR', 'WORKSITE_COUNTY','ORIGINAL_CERT_DATE', 'YR_SOURCE_PUB_1',
                             'YR_SOURCE_PUB_2','YR_SOURCE_PUB_2'], axis=1)

# %%
h1boverallv2
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0       I-200-12240-490687  CERTIFIED-WITHDRAWN     2012-08-27    2015-10-16
# 1       I-200-13053-847481  CERTIFIED-WITHDRAWN     2013-02-25    2016-01-13
# 2       I-200-13088-054259  CERTIFIED-WITHDRAWN     2013-04-23    2015-12-10
# 3       I-200-13144-034110  CERTIFIED-WITHDRAWN     2013-05-24    2016-01-19
# 4       I-200-13172-415116            WITHDRAWN     2013-06-26    2016-05-20
# 5       I-200-13219-306739  CERTIFIED-WITHDRAWN     2013-08-07    2015-10-30
# 6       I-200-13317-861241  CERTIFIED-WITHDRAWN     2013-11-20    2016-02-22
# 7       I-200-14037-755844  CERTIFIED-WITHDRAWN     2014-02-07    2015-11-16
# 8       I-200-14042-183163  CERTIFIED-WITHDRAWN     2014-02-19    2015-11-18
# 9       I-200-14072-690535            WITHDRAWN     2014-03-19    2016-03-03
# 10      I-200-14078-894857  CERTIFIED-WITHDRAWN     2014-03-19    2016-01-27
# ...

# %%
h1boverallv3=h1boverall.ix[:,['CASE_NUMBER','CASE_STATUS','CASE_SUBMITTED','DECISION_DATE',
                             'VISA_CLASS', 'EMPLOYMENT_START_DATE', 'EMPLOYMENT_END_DATE',
                             'EMPLOYER_NAME', 'EMPLOYER_CITY', 'EMPLOYER_STATE','JOB_TITLE',
                             'TOTAL_WORKERS','FULL_TIME_POSITION', 'WAGE_RATE_OF_PAY_FROM',
                             'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'H-1B_DEPENDENT',
                             'WILLFUL_VIOLATOR', 'WORKSITE_CITY', 'WORKSITE_STATE']]

# %%
h1boverallv3.to_excel('compressed.xlsx')
